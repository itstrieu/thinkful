# %% [markdown]
# Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:
#
# 1. Choose one variable and plot that variable four different ways.
# - Choose two continuous variables, and plot them three different ways.
# - Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sd = pd.read_csv('sd_major_cities.csv')
sd = sd.set_index('ID')
sd_la = sd.loc[622710]
sd_la_oss = sd_la[sd_la["Category"] == "Students receiving one or more in-school suspensions"]
print(sd_la_oss)
# Out:
#        Lea State                  LEA  Year  \
# ID
# 622710        CA  LOS ANGELES UNIFIED  2013
# 622710        CA  LOS ANGELES UNIFIED  2009
# 622710        CA  Los Angeles Unified  2015
# 622710        CA  LOS ANGELES UNIFIED  2011
#
#                                                  Category  Instances  \
# ID
# 622710  Students receiving one or more in-school suspe...        NaN
# 622710  Students receiving one or more in-school suspe...        NaN
# 622710  Students receiving one or more in-school suspe...        NaN
# 622710  Students receiving one or more in-school suspe...        NaN
#
#         American Indian or Alaska Native  Asian or Pacific Islander  Asian  \
# ID
# 622710                              10.0                        NaN   20.0
# 622710                               0.0                        0.0    NaN
# 622710                               4.0                        NaN   14.0
# 622710                               0.0                        NaN    0.0
#
# ...

# %%
sd.loc[622710, ["Year", "Category", "Instances", "Total"]]
# Out:
#         Year                                           Category  Instances  \
# ID
# 622710  2000                                Corporal punishment        NaN
# 622710  2000                           Out-of-school suspension        NaN
# 622710  2000  Expulsions (total with or without educational ...        NaN
# 622710  2000            Expulsions without educational services        NaN
# 622710  2000           Expulsions under zero-tolerance policies        NaN
# 622710  2000                                   Total enrollment        NaN
# 622710  2013                                Corporal punishment        NaN
# 622710  2013  Students receiving one or more in-school suspe...        NaN
# 622710  2013  Students receiving only one out-of-school susp...        NaN
# 622710  2013  Students receiving more than one out-of-school...        NaN
# 622710  2013               Expulsions with educational services        NaN
# ...

# %%
test = sd[(sd["Lea State"] == "CA") & (sd["Category"] == "Corporal punishment")]

test
# Out:
#        Lea State                  LEA  Year             Category  Instances  \
# ID
# 622710        CA  Los Angeles Unified  2000  Corporal punishment        NaN
# 622710        CA  LOS ANGELES UNIFIED  2013  Corporal punishment        NaN
# 622710        CA  LOS ANGELES UNIFIED  2009  Corporal punishment        NaN
# 622710        CA  Los Angeles Unified  2015  Corporal punishment        NaN
# 622710        CA  LOS ANGELES UNIFIED  2011  Corporal punishment        NaN
#
#         American Indian or Alaska Native  Asian or Pacific Islander  Asian  \
# ID
# 622710                               0.0                        0.0    NaN
# 622710                               0.0                        NaN    0.0
# 622710                               0.0                        0.0    NaN
# 622710                               0.0                        NaN    0.0
# 622710                               0.0                        NaN    0.0
#
# ...

# %%
sd[sd["Category"] == "Corporal punishment"]
# Out:
#         Lea State                           LEA  Year             Category  \
# ID
# 622710         CA           Los Angeles Unified  2000  Corporal punishment
# 1200390        FL   Dade County School District  2000  Corporal punishment
# 3200060        NV  Clark County School District  2000  Corporal punishment
# 4823640        TX                   Houston Isd  2000  Corporal punishment
# 1200390        FL                          DADE  2004  Corporal punishment
# 3200060        NV  CLARK COUNTY SCHOOL DISTRICT  2004  Corporal punishment
# 1200390        FL                          DADE  2006  Corporal punishment
# 3200060        NV  CLARK COUNTY SCHOOL DISTRICT  2006  Corporal punishment
# 1200390        FL                          DADE  2015  Corporal punishment
# 1200390        FL                          DADE  2011  Corporal punishment
# 4823640        TX                   HOUSTON ISD  2011  Corporal punishment
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
wdi = pd.read_csv("wdi.csv")

# %%
internet = wdi[wdi["Indicator Code"] == "IT.NET.USER.ZS"]
electricity = wdi[wdi["Indicator Code"] == "EG.ELC.ACCS.ZS"]
mobile = wdi[wdi["Indicator Code"] == "IT.CEL.SETS"]
securei = wdi[wdi["Indicator Code"] == "IT.NET.SECR"]
gdp = wdi[wdi["Indicator Code"] == "NY.GDP.PCAP.CD"]

# %%
wdi_2 = gdp.append(electricity).append(internet).append(securei).append(mobile)
wdi_2 = pd.DataFrame(wdi_2)

# %%
vn_2 = wdi_2[wdi_2["Country Code"] == "VNM"]
ind = wdi_2[wdi_2["Country Code"] == "IND"]
mmr = wdi_2[wdi_2["Country Code"] == "MMR"]
eth = wdi_2[wdi_2["Country Code"] == "ETH"]
syr = wdi_2[wdi_2["Country Code"] == "SYR"]
bgd = wdi_2[wdi_2["Country Code"] == "BGD"]
lka = wdi_2[wdi_2["Country Code"] == "LKA"]

# %%
countries = [vn_2, ind, mmr, eth, syr, bgd, lka]

countries_result = []

for country in countries:
   countries_result.append(country.drop(columns = ['Country Name', 'Country Code', 'Indicator Code']))



countries_result[0]
# Out:
#                                           Indicator Name  1960  1961  1962  \
# 413066                      GDP per capita (current US$)   NaN   NaN   NaN
# 412545           Access to electricity (% of population)   NaN   NaN   NaN
# 413209  Individuals using the Internet (% of population)   NaN   NaN   NaN
# 413930                           Secure Internet servers   NaN   NaN   NaN
# 413390                     Mobile cellular subscriptions   0.0   NaN   NaN
#
#         1963  1964  1965  1966  1967  1968    ...             2009  \
# 413066   NaN   NaN   NaN   NaN   NaN   NaN    ...     1.210691e+03
# 412545   NaN   NaN   NaN   NaN   NaN   NaN    ...     9.610000e+01
# 413209   NaN   NaN   NaN   NaN   NaN   NaN    ...     2.655000e+01
# 413930   NaN   NaN   NaN   NaN   NaN   NaN    ...              NaN
# 413390   NaN   NaN   0.0   NaN   NaN   NaN    ...     9.822398e+07
#
#                 2010          2011          2012          2013          2014  \
# 413066  1.310370e+03  1.515480e+03  1.722684e+03  1.871325e+03  2.012046e+03
# 412545  9.759113e+01  9.900000e+01  1.000000e+02  1.000000e+02  9.920000e+01
# 413209  3.065000e+01  3.507000e+01  3.680000e+01  3.850000e+01  4.100000e+01
# 413930  2.020000e+02  3.270000e+02  8.120000e+02  1.286000e+03  1.864000e+03
# 413390  1.115702e+08  1.273180e+08  1.316737e+08  1.237356e+08  1.361481e+08
#
#                 2015          2016          2017      2018
# 413066  2.065169e+03  2.170648e+03  2.342244e+03       NaN
# 412545  1.000000e+02  1.000000e+02           NaN       NaN
# 413209  4.350000e+01  4.650000e+01           NaN       NaN
# 413930  3.033000e+03  2.609800e+04  1.275840e+05  169056.0
# 413390  1.203241e+08  1.206002e+08  1.200162e+08       NaN
#
# [5 rows x 60 columns]

# %%
countries = [vn_2, ind, mmr, eth, syr, bgd, lka]
years = ["2010", "2011", "2012", "2013", "2014", "2015", "2016"]


for country in countries:
    country = country.drop(columns = ['Country Name', 'Country Code', 'Indicator Code'])

# %%
vn_2
# Out:
#        Country Name Country Code  \
# 413066      Vietnam          VNM
# 412545      Vietnam          VNM
# 413209      Vietnam          VNM
# 413930      Vietnam          VNM
# 413390      Vietnam          VNM
#
#                                           Indicator Name  Indicator Code  \
# 413066                      GDP per capita (current US$)  NY.GDP.PCAP.CD
# 412545           Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 413209  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 413930                           Secure Internet servers     IT.NET.SECR
# 413390                     Mobile cellular subscriptions     IT.CEL.SETS
#
#         1960  1961  1962  1963  1964  1965    ...             2009  \
# 413066   NaN   NaN   NaN   NaN   NaN   NaN    ...     1.210691e+03
# 412545   NaN   NaN   NaN   NaN   NaN   NaN    ...     9.610000e+01
# 413209   NaN   NaN   NaN   NaN   NaN   NaN    ...     2.655000e+01
# 413930   NaN   NaN   NaN   NaN   NaN   NaN    ...              NaN
# 413390   0.0   NaN   NaN   NaN   NaN   0.0    ...     9.822398e+07
#
#                 2010          2011          2012          2013          2014  \
# 413066  1.310370e+03  1.515480e+03  1.722684e+03  1.871325e+03  2.012046e+03
# 412545  9.759113e+01  9.900000e+01  1.000000e+02  1.000000e+02  9.920000e+01
# 413209  3.065000e+01  3.507000e+01  3.680000e+01  3.850000e+01  4.100000e+01
# 413930  2.020000e+02  3.270000e+02  8.120000e+02  1.286000e+03  1.864000e+03
# 413390  1.115702e+08  1.273180e+08  1.316737e+08  1.237356e+08  1.361481e+08
#
#                 2015          2016          2017      2018
# 413066  2.065169e+03  2.170648e+03  2.342244e+03       NaN
# 412545  1.000000e+02  1.000000e+02           NaN       NaN
# 413209  4.350000e+01  4.650000e+01           NaN       NaN
# 413930  3.033000e+03  2.609800e+04  1.275840e+05  169056.0
# 413390  1.203241e+08  1.206002e+08  1.200162e+08       NaN
#
# [5 rows x 63 columns]

# %%
for country in countrylist:
    country = pd.DataFrame(country)

# %%
for country in countrylist:
    country = country.transpose()

# %%
ind
# Out:
#        Country Name Country Code  \
# 217988        India          IND
# 217467        India          IND
# 218131        India          IND
# 218852        India          IND
# 218312        India          IND
#
#                                           Indicator Name  Indicator Code  \
# 217988                      GDP per capita (current US$)  NY.GDP.PCAP.CD
# 217467           Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 218131  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 218852                           Secure Internet servers     IT.NET.SECR
# 218312                     Mobile cellular subscriptions     IT.CEL.SETS
#
#              1960       1961       1962        1963        1964        1965  \
# 217988  81.284764  84.426437  88.914919  100.048592  114.315161  118.063382
# 217467        NaN        NaN        NaN         NaN         NaN         NaN
# 218131        NaN        NaN        NaN         NaN         NaN         NaN
# 218852        NaN        NaN        NaN         NaN         NaN         NaN
# 218312   0.000000        NaN        NaN         NaN         NaN    0.000000
#
#           ...             2009          2010          2011          2012  \
# 217988    ...     1.090318e+03  1.345770e+03  1.461672e+03  1.446985e+03
# 217467    ...     7.500000e+01  7.630000e+01  6.760000e+01  7.990000e+01
# 218131    ...     5.120000e+00  7.500000e+00  1.007000e+01  1.258006e+01
# 218852    ...              NaN  2.061000e+03  2.842000e+03  5.704000e+03
# 218312    ...     5.250900e+08  7.521900e+08  8.938625e+08  8.647209e+08
#
#                 2013          2014          2015          2016          2017  \
# 217988  1.452195e+03  1.576004e+03  1.606038e+03  1.717474e+03  1.942097e+03
# 217467  7.959911e+01  8.123951e+01  8.800000e+01  8.452682e+01           NaN
# 218131  1.510000e+01  2.100000e+01  2.600000e+01  2.954716e+01           NaN
# 218852  7.880000e+03  1.094100e+04  1.531300e+04  5.072300e+04  1.647910e+05
# 218312  8.863042e+08  9.440087e+08  1.001056e+09  1.127809e+09  1.168902e+09
#
#             2018
# 217988       NaN
# 217467       NaN
# 218131       NaN
# 218852  254032.0
# 218312       NaN
#
# [5 rows x 63 columns]

# %%
    x = x[['Year','GDP Per Capita',
 'Access to electricity (% of population)',
 'Individuals using the Internet (% of population)',
 'Secure Internet servers',
 'Mobile cellular subscriptions',]],
    x = x.reset_index(drop=True),
    x = x.astype(float),

# %%
ind
